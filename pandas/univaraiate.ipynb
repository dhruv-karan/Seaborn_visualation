# %%
import pandas as pd
reviews = pd.read_csv("../input/winemag-data_first150k.csv", index_col=0)
reviews.head(3)
# Out:
#   country           ...                              winery
# 0      US           ...                               Heitz
# 1   Spain           ...             Bodega Carmen Rodríguez
# 2      US           ...                            Macauley
#
# [3 rows x 10 columns]

# %%
reviews.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
reviews['province'].value_counts().head(10).plot.bar()

# %%
reviews['province'].value_counts().head(12).plot.bar()

# %%
(reviews['province'].value_counts().head(12)/len(reviews)).plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.line()

# %%
reviews['points'].value_counts().sort_index().plot.area()

# %%
reviews[reviews['price'] < 200]['price'].plot.hist()

# %%
reviews['points'].plot.hist()

# %%
reviews[reviews['price'] > 1500]
# Out:
#       country       ...                  winery
# 13318      US       ...                   Blair
# 34920  France       ...          Château Latour
# 34922  France       ...         Château Margaux
#
# [3 rows x 10 columns]

# %%
reviews['points'].value_counts().plot.
