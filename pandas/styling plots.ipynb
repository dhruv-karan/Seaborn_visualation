# %%
#------------------------ stylig pots

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16
)

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16,
    title='somethnig'
)

# %%
ax = reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16
)

ax.set_title('something',fontsize=30)
# Out:
# Text(0.5, 1.0, 'something')

# %%
#the above technique can be used in seaborn an in every function of pandas
